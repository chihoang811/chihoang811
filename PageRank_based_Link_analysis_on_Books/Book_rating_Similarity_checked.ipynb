# %% [markdown]
# <a href="https://colab.research.google.com/github/chihoang811/chihoang811/blob/main/PageRank_based_Link_analysis_on_Books/Book_rating_Similarity_checked.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***PageRank based Link Analysis on Books*** - Linh Chi HOANG
#
# *(Considering the similarity in book titles)*
#
#
# ---

# %% [markdown]
# ##### **1. Download Datasets**
#
#
# ---
#
#
#
#
# *   Please access your Kaggle account and download your API tokens for uploading the kaggle.json file and downloading the datasets
# *   For this project, only rating dataset was used

# %%
from google.colab import files
print("Please upload your kaggle.json file.")
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2025.11.12)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.5.1)

# %%
# !kaggle datasets download mohamedbakhet/amazon-books-reviews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mohamedbakhet/amazon-books-reviews
# License(s): CC0-1.0
# Downloading amazon-books-reviews.zip to /content
#  97% 1.03G/1.06G [00:18<00:00, 176MB/s]
# 100% 1.06G/1.06G [00:18<00:00, 62.4MB/s]

# %%
# !unzip amazon-books-reviews.zip
# Out:
# Archive:  amazon-books-reviews.zip
#   inflating: Books_rating.csv
#   inflating: books_data.csv

# %%
import pandas as pd
book_rating = pd.read_csv("Books_rating.csv")

# %% [markdown]
# ##### **2. Parameters settings**
#
#
# ---
#
#
# *   Note: Because of the limiation in RAM, this project used only popular books, which have at least 81 unique users

# %%
USE_SUBSAMPLE = True
MIN_RATING = 4 # keep onlybooks with score >= 4
MIN_USERS_PER_BOOK = 81 # choose only books rated by at least 81 users
MIN_SHARED_USERS_FOR_EDGES = 2 # edges are created only if for each pair of book there are at least 2 mutual users rating them

# %% [markdown]
# ##### **3. Data Preprocessing with dataset *book_ratings***
#
#
# ---
#
#
# *   Choose only books with **review/score ≥ 4.0**
# *   Check NAN values
# *   Normalize book titles
# *   Check similar book titles (using Jaccard similarity)
# *   Create Weight matrix W
# *   Create Transition matrix M

# %%
# Check for NaN values
nan_check = book_rating.isnull()
print(nan_check.sum())

# Remove rows with NaN values
book_rating = book_rating.dropna()
# Out:
# Id                          0
# Title                     208
# Price                 2518829
# User_id                561787
# profileName            561905
# review/helpfulness          0
# review/score                0
# review/time                 0
# review/summary            407
# review/text                 8
# dtype: int64

# %%
# Normalize the titles (Because there are some books whose titles are the same but written in different forms)
import re

def normalized_title(t):
    t = t.lower().strip()
    t = re.sub(r'[^a-z0-9 ]+', '', t)   # remove punctuation
    t = re.sub(r'\s+', ' ', t)          # collapse spaces
    return t

book_rating['Title_cleaned'] = book_rating['Title'].apply(normalized_title)

# Filter ratings (>= 4) and select Title
filtered_books = book_rating[book_rating['review/score'] >= MIN_RATING][['Title_cleaned', 'User_id', 'review/score']]

# %%
# Count how many unique users rated each book
book_user_counts = filtered_books.groupby("Title_cleaned")["User_id"].nunique()

if USE_SUBSAMPLE:
  # Keep only books with at least 81 unique users
  popular_books = book_user_counts[book_user_counts >= MIN_USERS_PER_BOOK].index
  filtered_books = filtered_books[filtered_books["Title_cleaned"].isin(popular_books)]
else:
 popular_books = book_user_counts.index

# %%
filtered_books
# Out:
#                                     Title_cleaned         User_id  \
# 38660    gods and kings chronicles of the kings 1   A7IMBNFYANPNV
# 38661    gods and kings chronicles of the kings 1  A1WV4Q44JE40UF
# 38662    gods and kings chronicles of the kings 1  A32MYDPSMCHT1L
# 38663    gods and kings chronicles of the kings 1   AAOJ5T6VS5Z6O
# 38664    gods and kings chronicles of the kings 1  A2X1OYBRURS04R
# ...                                           ...             ...
# 2994351               first 100 words bright baby   AIFSOGUNXFADJ
# 2994352               first 100 words bright baby  A2B9B5F9FQ4JJ8
# 2994354               first 100 words bright baby  A2G9EZ3R716RH1
# 2994355               first 100 words bright baby  A37P45ZC5DSAJJ
# 2994356               first 100 words bright baby  A2LGDRB4P9DFG5
#
#          review/score
# 38660             5.0
# 38661             5.0
# 38662             5.0
# 38663             5.0
# 38664             5.0
# ...               ...
# 2994351           5.0
# 2994352           4.0
# 2994354           4.0
# 2994355           5.0
# 2994356           5.0
#
# [75789 rows x 3 columns]

# %% [markdown]
# ###### *Find similarity applying Jaccard function*

# %%
# Number of unique titles
nunique_titles = filtered_books["Title_cleaned"].nunique()
print(nunique_titles)
# Out:
# 378

# %%
# Convert each normalized title into a set of words
def title_to_set(title):
    return set(title.split())

# %%
# Jaccard similarity function
def jaccard_similarity(set1, set2):
    if not set1 and not set2:
        return 0.0
    return len(set1 & set2) / len(set1 | set2)

# %%
# Apply Jaccard function on all unique titles
import itertools

unique_titles = filtered_books["Title_cleaned"].unique()

# Convert each title to a set of words
title_sets = {t: title_to_set(t) for t in unique_titles}

similarities = []

for t1, t2 in itertools.combinations(unique_titles, 2):
    s1 = title_sets[t1]
    s2 = title_sets[t2]
    sim = jaccard_similarity(s1, s2)
    similarities.append((t1, t2, sim))

similar_df = pd.DataFrame(similarities, columns=['Title1', 'Title2', 'Sim'])
similar_df
# Out:
#                                                   Title1  \
# 0               gods and kings chronicles of the kings 1
# 1               gods and kings chronicles of the kings 1
# 2               gods and kings chronicles of the kings 1
# 3               gods and kings chronicles of the kings 1
# 4               gods and kings chronicles of the kings 1
# ...                                                  ...
# 71248                           13 little blue envelopes
# 71249                           13 little blue envelopes
# 71250  1491 new revelations of the americas before co...
# 71251  1491 new revelations of the americas before co...
# 71252  six days of war june 1967 and the making of th...
#
#                                                   Title2       Sim
# 0                              the mayor of casterbridge  0.222222
# 1      hyperspace a scientific odyssey through parall...  0.111111
# 2      solitary witch the ultimate book of shadows fo...  0.133333
# 3                stitch n bitch crochet the happy hooker  0.076923
# 4      why men love bitches from doormat to dreamgirl...  0.000000
# ...                                                  ...       ...
# 71248  six days of war june 1967 and the making of th...  0.000000
# 71249                        first 100 words bright baby  0.000000
# 71250  six days of war june 1967 and the making of th...  0.111111
# 71251                        first 100 words bright baby  0.000000
# 71252                        first 100 words bright baby  0.000000
#
# [71253 rows x 3 columns]

# %% [markdown]
# ###### *Merge titles whose Jaccard similarity ≥ 0.4*

# %%
# Build clusters of similar titles
# Keep only pairs with Jaccard >= 0.4
jaccard_filtered = similar_df[similar_df['Sim'] >= 0.4].copy()

clusters = []
visited = set()

# We will treat each connected group of titles as a cluster
for t in pd.unique(jaccard_filtered[['Title1', 'Title2']].values.ravel()):
    if t in visited:
        continue

    # start a new cluster with this title
    group = {t}
    changed = True

    # keep adding titles that are linked to any title in the group
    while changed:
        changed = False
        for _, row in jaccard_filtered.iterrows():
            a, b = row['Title1'], row['Title2']
            if a in group and b not in group:
                group.add(b)
                changed = True
            elif b in group and a not in group:
                group.add(a)
                changed = True

    visited |= group
    clusters.append(group)

print("Number of clusters:", len(clusters))
# Out:
# Number of clusters: 12

# %%
# Choose one canonical title per cluster
def choose_canonical(group):
    return min(group, key=len)

mapping = {}

for group in clusters:
    canon = choose_canonical(group)
    for t in group:
        mapping[t] = canon

filtered_books['Title_final'] = filtered_books['Title_cleaned'].map(mapping).fillna(filtered_books['Title_cleaned'])

# %%
filtered_books = filtered_books[['Title_final', 'User_id', 'review/score']]
filtered_books
# Out:
#                                       Title_final         User_id  \
# 38660    gods and kings chronicles of the kings 1   A7IMBNFYANPNV
# 38661    gods and kings chronicles of the kings 1  A1WV4Q44JE40UF
# 38662    gods and kings chronicles of the kings 1  A32MYDPSMCHT1L
# 38663    gods and kings chronicles of the kings 1   AAOJ5T6VS5Z6O
# 38664    gods and kings chronicles of the kings 1  A2X1OYBRURS04R
# ...                                           ...             ...
# 2994351               first 100 words bright baby   AIFSOGUNXFADJ
# 2994352               first 100 words bright baby  A2B9B5F9FQ4JJ8
# 2994354               first 100 words bright baby  A2G9EZ3R716RH1
# 2994355               first 100 words bright baby  A37P45ZC5DSAJJ
# 2994356               first 100 words bright baby  A2LGDRB4P9DFG5
#
#          review/score
# 38660             5.0
# 38661             5.0
# 38662             5.0
# 38663             5.0
# 38664             5.0
# ...               ...
# 2994351           5.0
# 2994352           4.0
# 2994354           4.0
# 2994355           5.0
# 2994356           5.0
#
# [75789 rows x 3 columns]

# %% [markdown]
# ###### *Create the Transition matrix M*

# %%
# For each pair of books, count how many users liked both
import numpy as np

# Build a user-book matrix (rows are users, columns are books, value =1 if user rated book >= 4)
book_user = filtered_books.drop_duplicates().pivot_table(
    index='User_id',
    columns='Title_final',
    values='Title_final',
    aggfunc='count',
    fill_value=0
)
book_user = (book_user > 0).astype(int)

# Build Weighted adjacency matrix W where W[i,j] is the number of shared users between book i and book j
W = book_user.T.dot(book_user)

print(W.shape)
W.head()
# Out:
# (342, 342)
# Title_final                                         13 little blue envelopes  \
# Title_final
# 13 little blue envelopes                                                 109
# 1491 new revelations of the americas before col...                         0
# 1632 the assiti shards                                                     0
# 1906                                                                       0
# 23 minutes in hell one mans story about what he...                         0
#
# Title_final                                         1491 new revelations of the americas before columbus  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                345
# 1632 the assiti shards                                                                              1
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
# Title_final                                         1632 the assiti shards  \
# Title_final
# 13 little blue envelopes                                                 0
# 1491 new revelations of the americas before col...                       1
# 1632 the assiti shards                                                 141
# 1906                                                                     0
# 23 minutes in hell one mans story about what he...                       0
#
# Title_final                                         1906  \
# Title_final
# 13 little blue envelopes                               0
# 1491 new revelations of the americas before col...     0
# 1632 the assiti shards                                 0
# 1906                                                  88
# 23 minutes in hell one mans story about what he...     0
#
# Title_final                                         23 minutes in hell one mans story about what he saw heard and felt in that place of torment  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                346
#
# Title_final                                         500 lowcarb recipes 500 recipes from snacks to dessert that the whole family will love  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
# Title_final                                         a breath of snow and ashes outlander  \
# Title_final
# 13 little blue envelopes                                                               0
# 1491 new revelations of the americas before col...                                     0
# 1632 the assiti shards                                                                 1
# 1906                                                                                   0
# 23 minutes in hell one mans story about what he...                                     0
#
# Title_final                                         a bride most begrudging  \
# Title_final
# 13 little blue envelopes                                                  0
# 1491 new revelations of the americas before col...                        0
# 1632 the assiti shards                                                    1
# 1906                                                                      0
# 23 minutes in hell one mans story about what he...                        0
#
# Title_final                                         a caress of twilight meredith gentry book 2  \
# Title_final
# 13 little blue envelopes                                                                      0
# 1491 new revelations of the americas before col...                                            0
# 1632 the assiti shards                                                                        2
# 1906                                                                                          0
# 23 minutes in hell one mans story about what he...                                            0
#
# Title_final                                         a certain slant of light  \
# Title_final
# 13 little blue envelopes                                                   3
# 1491 new revelations of the americas before col...                         0
# 1632 the assiti shards                                                     0
# 1906                                                                       0
# 23 minutes in hell one mans story about what he...                         1
#
# Title_final                                         ...  \
# Title_final                                         ...
# 13 little blue envelopes                            ...
# 1491 new revelations of the americas before col...  ...
# 1632 the assiti shards                              ...
# 1906                                                ...
# 23 minutes in hell one mans story about what he...  ...
#
# Title_final                                         where the sidewalk ends poems and drawings  \
# Title_final
# 13 little blue envelopes                                                                     0
# 1491 new revelations of the americas before col...                                           1
# 1632 the assiti shards                                                                       0
# 1906                                                                                         0
# 23 minutes in hell one mans story about what he...                                           1
#
# Title_final                                         who wrote the bible  \
# Title_final
# 13 little blue envelopes                                              0
# 1491 new revelations of the americas before col...                    1
# 1632 the assiti shards                                                0
# 1906                                                                  0
# 23 minutes in hell one mans story about what he...                    0
#
# Title_final                                         why men love bitches from doormat to dreamgirl a womans guide to holding her own in a relationship  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  1
#
# Title_final                                         wicked the grimmerie a behindthescenes look at the hit broadway musical  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
# Title_final                                         wizards first rule sword of truth book 1  \
# Title_final
# 13 little blue envelopes                                                                   0
# 1491 new revelations of the americas before col...                                         1
# 1632 the assiti shards                                                                     3
# 1906                                                                                       0
# 23 minutes in hell one mans story about what he...                                         0
#
# Title_final                                         words that work its not what you say its what people hear  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  1
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
# Title_final                                         wuthering heights  \
# Title_final
# 13 little blue envelopes                                            0
# 1491 new revelations of the americas before col...                  3
# 1632 the assiti shards                                              0
# 1906                                                                0
# 23 minutes in hell one mans story about what he...                  0
#
# Title_final                                         yours until dawn  \
# Title_final
# 13 little blue envelopes                                           0
# 1491 new revelations of the americas before col...                 0
# 1632 the assiti shards                                             1
# 1906                                                               0
# 23 minutes in hell one mans story about what he...                 0
#
# Title_final                                         zen in the martial arts  \
# Title_final
# 13 little blue envelopes                                                  0
# 1491 new revelations of the americas before col...                        0
# 1632 the assiti shards                                                    0
# 1906                                                                      0
# 23 minutes in hell one mans story about what he...                        0
#
# Title_final                                         zen shorts caldecott honor book
# Title_final
# 13 little blue envelopes                                                          1
# 1491 new revelations of the americas before col...                                0
# 1632 the assiti shards                                                            0
# 1906                                                                              0
# 23 minutes in hell one mans story about what he...                                0
#
# [5 rows x 342 columns]

# %%
# Remove self-counts on the diagonal
np.fill_diagonal(W.values, 0)

# Keep only strong edges
W = W.where(W >= MIN_SHARED_USERS_FOR_EDGES, 0)

W.head()
# Out:
# Title_final                                         13 little blue envelopes  \
# Title_final
# 13 little blue envelopes                                                   0
# 1491 new revelations of the americas before col...                         0
# 1632 the assiti shards                                                     0
# 1906                                                                       0
# 23 minutes in hell one mans story about what he...                         0
#
# Title_final                                         1491 new revelations of the americas before columbus  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
# Title_final                                         1632 the assiti shards  \
# Title_final
# 13 little blue envelopes                                                 0
# 1491 new revelations of the americas before col...                       0
# 1632 the assiti shards                                                   0
# 1906                                                                     0
# 23 minutes in hell one mans story about what he...                       0
#
# Title_final                                         1906  \
# Title_final
# 13 little blue envelopes                               0
# 1491 new revelations of the americas before col...     0
# 1632 the assiti shards                                 0
# 1906                                                   0
# 23 minutes in hell one mans story about what he...     0
#
# Title_final                                         23 minutes in hell one mans story about what he saw heard and felt in that place of torment  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
# Title_final                                         500 lowcarb recipes 500 recipes from snacks to dessert that the whole family will love  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
# Title_final                                         a breath of snow and ashes outlander  \
# Title_final
# 13 little blue envelopes                                                               0
# 1491 new revelations of the americas before col...                                     0
# 1632 the assiti shards                                                                 0
# 1906                                                                                   0
# 23 minutes in hell one mans story about what he...                                     0
#
# Title_final                                         a bride most begrudging  \
# Title_final
# 13 little blue envelopes                                                  0
# 1491 new revelations of the americas before col...                        0
# 1632 the assiti shards                                                    0
# 1906                                                                      0
# 23 minutes in hell one mans story about what he...                        0
#
# Title_final                                         a caress of twilight meredith gentry book 2  \
# Title_final
# 13 little blue envelopes                                                                      0
# 1491 new revelations of the americas before col...                                            0
# 1632 the assiti shards                                                                        2
# 1906                                                                                          0
# 23 minutes in hell one mans story about what he...                                            0
#
# Title_final                                         a certain slant of light  \
# Title_final
# 13 little blue envelopes                                                   3
# 1491 new revelations of the americas before col...                         0
# 1632 the assiti shards                                                     0
# 1906                                                                       0
# 23 minutes in hell one mans story about what he...                         0
#
# Title_final                                         ...  \
# Title_final                                         ...
# 13 little blue envelopes                            ...
# 1491 new revelations of the americas before col...  ...
# 1632 the assiti shards                              ...
# 1906                                                ...
# 23 minutes in hell one mans story about what he...  ...
#
# Title_final                                         where the sidewalk ends poems and drawings  \
# Title_final
# 13 little blue envelopes                                                                     0
# 1491 new revelations of the americas before col...                                           0
# 1632 the assiti shards                                                                       0
# 1906                                                                                         0
# 23 minutes in hell one mans story about what he...                                           0
#
# Title_final                                         who wrote the bible  \
# Title_final
# 13 little blue envelopes                                              0
# 1491 new revelations of the americas before col...                    0
# 1632 the assiti shards                                                0
# 1906                                                                  0
# 23 minutes in hell one mans story about what he...                    0
#
# Title_final                                         why men love bitches from doormat to dreamgirl a womans guide to holding her own in a relationship  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
# Title_final                                         wicked the grimmerie a behindthescenes look at the hit broadway musical  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
# Title_final                                         wizards first rule sword of truth book 1  \
# Title_final
# 13 little blue envelopes                                                                   0
# 1491 new revelations of the americas before col...                                         0
# 1632 the assiti shards                                                                     3
# 1906                                                                                       0
# 23 minutes in hell one mans story about what he...                                         0
#
# Title_final                                         words that work its not what you say its what people hear  \
# Title_final
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
# Title_final                                         wuthering heights  \
# Title_final
# 13 little blue envelopes                                            0
# 1491 new revelations of the americas before col...                  3
# 1632 the assiti shards                                              0
# 1906                                                                0
# 23 minutes in hell one mans story about what he...                  0
#
# Title_final                                         yours until dawn  \
# Title_final
# 13 little blue envelopes                                           0
# 1491 new revelations of the americas before col...                 0
# 1632 the assiti shards                                             0
# 1906                                                               0
# 23 minutes in hell one mans story about what he...                 0
#
# Title_final                                         zen in the martial arts  \
# Title_final
# 13 little blue envelopes                                                  0
# 1491 new revelations of the americas before col...                        0
# 1632 the assiti shards                                                    0
# 1906                                                                      0
# 23 minutes in hell one mans story about what he...                        0
#
# Title_final                                         zen shorts caldecott honor book
# Title_final
# 13 little blue envelopes                                                          0
# 1491 new revelations of the americas before col...                                0
# 1632 the assiti shards                                                            0
# 1906                                                                              0
# 23 minutes in hell one mans story about what he...                                0
#
# [5 rows x 342 columns]

# %%
# Transition pronability matrix M
A = W.to_numpy().astype(float)   # A[i, j] = weight from book j to book i

# Column sums: total outgoing weight from each book j
col_sums = A.sum(axis=0)

# Handle dangling nodes (books with no outgoing edges)
dangling = (col_sums == 0)
if np.any(dangling):
    A[:, dangling] = 1.0  # For dangling columns, pretend they link equally to all books
    col_sums = A.sum(axis=0)

# Normalize columns so that each column sums to 1
M_np = A / col_sums

M = pd.DataFrame(M_np, index=W.index, columns=W.columns)

# %%
print(M.shape)
print("Column sums (=1):")
print(M.sum(axis=0))
# Out:
# (342, 342)
# Column sums (should be ~1):
# Title_final
# 13 little blue envelopes                                                                       1.0
# 1491 new revelations of the americas before columbus                                           1.0
# 1632 the assiti shards                                                                         1.0
# 1906                                                                                           1.0
# 23 minutes in hell one mans story about what he saw heard and felt in that place of torment    1.0
#                                                                                               ...
# words that work its not what you say its what people hear                                      1.0
# wuthering heights                                                                              1.0
# yours until dawn                                                                               1.0
# zen in the martial arts                                                                        1.0
# zen shorts caldecott honor book                                                                1.0
# Length: 342, dtype: float64

# %% [markdown]
# ##### **4. Apply PageRank-based Link Analysis**
#
#
# ---
#
#
#
#
# *   Mathematical term: `v'= βMv + (1-β)e/n`

# %%
def pagerank(M, alpha=0.85, tol=1e-8, max_iter=100):
    M = M.to_numpy() if isinstance(M, pd.DataFrame) else M
    N = M.shape[0]
    p = np.ones(N) / N
    teleport = (1 - alpha) / N

    for _ in range(max_iter):
        p_new = alpha * (M @ p) + teleport
        if np.linalg.norm(p_new - p, 1) < tol:
            break
        p = p_new
    return p

# %%
scores = pagerank(M)

# Attach book titles
pagerank_scores = pd.Series(scores, index=M.index, name='PageRank')

# Sort from most important book to least
pagerank_scores = pagerank_scores.sort_values(ascending=False)

pagerank_scores = pd.DataFrame(pagerank_scores)
pagerank_scores
# Out:
#                                                     PageRank
# Title_final
# the tao of pooh                                     0.046578
# jane eyre new windmill                              0.037223
# jane eyre large print                               0.037223
# a christmas carol in prose being a ghost story ...  0.025420
# a christmas carol classic fiction                   0.025420
# ...                                                      ...
# cliffstestprep math review for standardized tes...  0.000523
# the wealthy spirit daily affirmations for finan...  0.000523
# algebra survival guide a conversational guide f...  0.000523
# adobe photoshop cs2 oneonone                        0.000523
# adult allinone course lessontheorytechnic level 1   0.000523
#
# [342 rows x 1 columns]
