# %% [markdown]
# <a href="https://colab.research.google.com/github/chihoang811/chihoang811/blob/main/PageRank_based_Link_analysis_on_Books/Book_rating_no_Similarity_checked.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***PageRank based Link Analysis on Books*** - Linh Chi HOANG
#
# *(Without considering the similarity)*
#
#
# ---

# %% [markdown]
# ##### **1. Download Datasets**
#
#
#
# ---
#
#
# *   Please access your Kaggle account and download your API tokens for uploading the kaggle.json file and downloading the datasets
# *   For this project, only rating dataset was used

# %%
from google.colab import files
print("Please upload your kaggle.json file.")
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2025.11.12)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.5.1)

# %%
# !kaggle datasets download mohamedbakhet/amazon-books-reviews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mohamedbakhet/amazon-books-reviews
# License(s): CC0-1.0
# Downloading amazon-books-reviews.zip to /content
#  96% 1.02G/1.06G [00:06<00:00, 101MB/s]
# 100% 1.06G/1.06G [00:07<00:00, 162MB/s]

# %%
# !unzip amazon-books-reviews.zip
# Out:
# Archive:  amazon-books-reviews.zip
#   inflating: Books_rating.csv
#   inflating: books_data.csv

# %%
import pandas as pd
book_rating = pd.read_csv("Books_rating.csv")

# %% [markdown]
# ##### **2. Parameters settings**
#
#
# ---
#
#
#
# *   Note: Because of the limiation in RAM, this project used only popular books, which have at least 81 unique users

# %%
USE_SUBSAMPLE = True
MIN_RATING = 4 # keep onlybooks with score >= 4
MIN_USERS_PER_BOOK = 81 # choose only books rated by at least 81 users
MIN_SHARED_USERS_FOR_EDGES = 2 # edges are created only if for each pair of book there are at least 2 mutual users rating them

# %% [markdown]
# ##### **3. Data Preprocessing with dataset *book_ratings***
#
#
#
# ---
#
#
# *   Choose only books with **review/score ≥ 4.0**
# *   Check NAN values
# *   Create Weight matrix W
# *   Create Transition matrix M

# %%
# Check for NaN values
nan_check = book_rating.isnull()
print(nan_check.sum())

# Remove rows with NaN values
book_rating = book_rating.dropna()
# Out:
# Id                          0
# Title                     208
# Price                 2518829
# User_id                561787
# profileName            561905
# review/helpfulness          0
# review/score                0
# review/time                 0
# review/summary            407
# review/text                 8
# dtype: int64

# %%
# Filter ratings (>= 4)
filtered_books = book_rating[book_rating['review/score'] >= MIN_RATING][['Title', 'User_id', 'review/score']]

# %%
# Count how many unique users rated each book
book_user_counts = filtered_books.groupby("Title")["User_id"].nunique()

if USE_SUBSAMPLE:
  # Keep only books with at least 81 unique users
  popular_books = book_user_counts[book_user_counts >= MIN_USERS_PER_BOOK].index
  filtered_books = filtered_books[filtered_books["Title"].isin(popular_books)]
else:
 popular_books = book_user_counts.index

# %%
filtered_books
# Out:
#                                                Title         User_id  \
# 38660    Gods and Kings (Chronicles of the Kings #1)   A7IMBNFYANPNV
# 38661    Gods and Kings (Chronicles of the Kings #1)  A1WV4Q44JE40UF
# 38662    Gods and Kings (Chronicles of the Kings #1)  A32MYDPSMCHT1L
# 38663    Gods and Kings (Chronicles of the Kings #1)   AAOJ5T6VS5Z6O
# 38664    Gods and Kings (Chronicles of the Kings #1)  A2X1OYBRURS04R
# ...                                              ...             ...
# 2994351                First 100 Words (Bright Baby)   AIFSOGUNXFADJ
# 2994352                First 100 Words (Bright Baby)  A2B9B5F9FQ4JJ8
# 2994354                First 100 Words (Bright Baby)  A2G9EZ3R716RH1
# 2994355                First 100 Words (Bright Baby)  A37P45ZC5DSAJJ
# 2994356                First 100 Words (Bright Baby)  A2LGDRB4P9DFG5
#
#          review/score
# 38660             5.0
# 38661             5.0
# 38662             5.0
# 38663             5.0
# 38664             5.0
# ...               ...
# 2994351           5.0
# 2994352           4.0
# 2994354           4.0
# 2994355           5.0
# 2994356           5.0
#
# [75789 rows x 3 columns]

# %%
user_num = filtered_books["User_id"].nunique()
print(user_num)

title_num = filtered_books["Title"].nunique()
print(title_num)
# Out:
# 60081
# 380

# %% [markdown]
# ###### *Create the Transition matrix M*

# %%
# For each pair of books, count how many users liked both
import numpy as np

# Build a user-book matrix (rows are users, columns are books, value =1 if user rated book >= 4)
book_user = filtered_books.drop_duplicates().pivot_table(
    index='User_id',
    columns='Title',
    values='Title',
    aggfunc='count',
    fill_value=0
)
book_user = (book_user > 0).astype(int)

# Build Weighted adjacency matrix W where W[i,j] is the number of shared users between book i and book j
W = book_user.T.dot(book_user)

print(W.shape)
W.head()
# Out:
# (380, 380)
# Title                                               13 Little Blue Envelopes  \
# Title
# 13 Little Blue Envelopes                                                 109
# 1491: New Revelations of the Americas Before Co...                         0
# 1632 (The Assiti Shards)                                                   0
# 1906                                                                       0
# 23 Minutes In Hell: One Man's Story About What ...                         0
#
# Title                                               1491: New Revelations of the Americas Before Columbus  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                345
# 1632 (The Assiti Shards)                                                                            1
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  0
#
# Title                                               1632 (The Assiti Shards)  \
# Title
# 13 Little Blue Envelopes                                                   0
# 1491: New Revelations of the Americas Before Co...                         1
# 1632 (The Assiti Shards)                                                 141
# 1906                                                                       0
# 23 Minutes In Hell: One Man's Story About What ...                         0
#
# Title                                               1906  \
# Title
# 13 Little Blue Envelopes                               0
# 1491: New Revelations of the Americas Before Co...     0
# 1632 (The Assiti Shards)                               0
# 1906                                                  88
# 23 Minutes In Hell: One Man's Story About What ...     0
#
# Title                                               23 Minutes In Hell: One Man's Story About What He Saw, Heard, and Felt in that Place of Torment  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                  0
# 1632 (The Assiti Shards)                                                                            0
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                346
#
# Title                                               500 Low-Carb Recipes: 500 Recipes from Snacks to Dessert, That the Whole Family Will Love  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                  0
# 1632 (The Assiti Shards)                                                                            0
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  0
#
# Title                                               A Breath of Snow and Ashes (Outlander)  \
# Title
# 13 Little Blue Envelopes                                                                 0
# 1491: New Revelations of the Americas Before Co...                                       0
# 1632 (The Assiti Shards)                                                                 1
# 1906                                                                                     0
# 23 Minutes In Hell: One Man's Story About What ...                                       0
#
# Title                                               A Bride Most Begrudging  \
# Title
# 13 Little Blue Envelopes                                                  0
# 1491: New Revelations of the Americas Before Co...                        0
# 1632 (The Assiti Shards)                                                  1
# 1906                                                                      0
# 23 Minutes In Hell: One Man's Story About What ...                        0
#
# Title                                               A Caress of Twilight (Meredith Gentry, Book 2)  \
# Title
# 13 Little Blue Envelopes                                                                         0
# 1491: New Revelations of the Americas Before Co...                                               0
# 1632 (The Assiti Shards)                                                                         2
# 1906                                                                                             0
# 23 Minutes In Hell: One Man's Story About What ...                                               0
#
# Title                                               A Certain Slant of Light  \
# Title
# 13 Little Blue Envelopes                                                   3
# 1491: New Revelations of the Americas Before Co...                         0
# 1632 (The Assiti Shards)                                                   0
# 1906                                                                       0
# 23 Minutes In Hell: One Man's Story About What ...                         1
#
# Title                                               ...  \
# Title                                               ...
# 13 Little Blue Envelopes                            ...
# 1491: New Revelations of the Americas Before Co...  ...
# 1632 (The Assiti Shards)                            ...
# 1906                                                ...
# 23 Minutes In Hell: One Man's Story About What ...  ...
#
# Title                                               Wizard's First Rule (Sword of Truth, Book 1)  \
# Title
# 13 Little Blue Envelopes                                                                       0
# 1491: New Revelations of the Americas Before Co...                                             1
# 1632 (The Assiti Shards)                                                                       3
# 1906                                                                                           0
# 23 Minutes In Hell: One Man's Story About What ...                                             0
#
# Title                                               Words That Work: It's Not What You Say, It's What People Hear  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                  1
# 1632 (The Assiti Shards)                                                                            0
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  0
#
# Title                                               Wuthering Heights  \
# Title
# 13 Little Blue Envelopes                                            0
# 1491: New Revelations of the Americas Before Co...                  3
# 1632 (The Assiti Shards)                                            0
# 1906                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                  0
#
# Title                                               Year of Wonders (Turtleback School & Library Binding Edition)  \
# Title
# 13 Little Blue Envelopes                                                                            1
# 1491: New Revelations of the Americas Before Co...                                                  5
# 1632 (The Assiti Shards)                                                                            1
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  1
#
# Title                                               Yours Until Dawn  \
# Title
# 13 Little Blue Envelopes                                           0
# 1491: New Revelations of the Americas Before Co...                 0
# 1632 (The Assiti Shards)                                           1
# 1906                                                               0
# 23 Minutes In Hell: One Man's Story About What ...                 0
#
# Title                                               Zane's Afterburn: A Novel  \
# Title
# 13 Little Blue Envelopes                                                    0
# 1491: New Revelations of the Americas Before Co...                          0
# 1632 (The Assiti Shards)                                                    0
# 1906                                                                        0
# 23 Minutes In Hell: One Man's Story About What ...                          0
#
# Title                                               Zen Shorts (Caldecott Honor Book)  \
# Title
# 13 Little Blue Envelopes                                                            1
# 1491: New Revelations of the Americas Before Co...                                  0
# 1632 (The Assiti Shards)                                                            0
# 1906                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                  0
#
# Title                                               Zen in the Martial Arts  \
# Title
# 13 Little Blue Envelopes                                                  0
# 1491: New Revelations of the Americas Before Co...                        0
# 1632 (The Assiti Shards)                                                  0
# 1906                                                                      0
# 23 Minutes In Hell: One Man's Story About What ...                        0
#
# Title                                               comeback - a mother and daughter's journey through hell and back  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                  1
# 1632 (The Assiti Shards)                                                                            0
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  0
#
# Title                                               the Picture of Dorian Gray
# Title
# 13 Little Blue Envelopes                                                     1
# 1491: New Revelations of the Americas Before Co...                           2
# 1632 (The Assiti Shards)                                                     0
# 1906                                                                         0
# 23 Minutes In Hell: One Man's Story About What ...                           0
#
# [5 rows x 380 columns]

# %%
# Remove self-counts on the diagonal
np.fill_diagonal(W.values, 0)

# Keep only strong edges
W = W.where(W >= MIN_SHARED_USERS_FOR_EDGES, 0)

W.head()
# Out:
# Title                                               13 Little Blue Envelopes  \
# Title
# 13 Little Blue Envelopes                                                   0
# 1491: New Revelations of the Americas Before Co...                         0
# 1632 (The Assiti Shards)                                                   0
# 1906                                                                       0
# 23 Minutes In Hell: One Man's Story About What ...                         0
#
# Title                                               1491: New Revelations of the Americas Before Columbus  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                  0
# 1632 (The Assiti Shards)                                                                            0
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  0
#
# Title                                               1632 (The Assiti Shards)  \
# Title
# 13 Little Blue Envelopes                                                   0
# 1491: New Revelations of the Americas Before Co...                         0
# 1632 (The Assiti Shards)                                                   0
# 1906                                                                       0
# 23 Minutes In Hell: One Man's Story About What ...                         0
#
# Title                                               1906  \
# Title
# 13 Little Blue Envelopes                               0
# 1491: New Revelations of the Americas Before Co...     0
# 1632 (The Assiti Shards)                               0
# 1906                                                   0
# 23 Minutes In Hell: One Man's Story About What ...     0
#
# Title                                               23 Minutes In Hell: One Man's Story About What He Saw, Heard, and Felt in that Place of Torment  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                  0
# 1632 (The Assiti Shards)                                                                            0
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  0
#
# Title                                               500 Low-Carb Recipes: 500 Recipes from Snacks to Dessert, That the Whole Family Will Love  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                  0
# 1632 (The Assiti Shards)                                                                            0
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  0
#
# Title                                               A Breath of Snow and Ashes (Outlander)  \
# Title
# 13 Little Blue Envelopes                                                                 0
# 1491: New Revelations of the Americas Before Co...                                       0
# 1632 (The Assiti Shards)                                                                 0
# 1906                                                                                     0
# 23 Minutes In Hell: One Man's Story About What ...                                       0
#
# Title                                               A Bride Most Begrudging  \
# Title
# 13 Little Blue Envelopes                                                  0
# 1491: New Revelations of the Americas Before Co...                        0
# 1632 (The Assiti Shards)                                                  0
# 1906                                                                      0
# 23 Minutes In Hell: One Man's Story About What ...                        0
#
# Title                                               A Caress of Twilight (Meredith Gentry, Book 2)  \
# Title
# 13 Little Blue Envelopes                                                                         0
# 1491: New Revelations of the Americas Before Co...                                               0
# 1632 (The Assiti Shards)                                                                         2
# 1906                                                                                             0
# 23 Minutes In Hell: One Man's Story About What ...                                               0
#
# Title                                               A Certain Slant of Light  \
# Title
# 13 Little Blue Envelopes                                                   3
# 1491: New Revelations of the Americas Before Co...                         0
# 1632 (The Assiti Shards)                                                   0
# 1906                                                                       0
# 23 Minutes In Hell: One Man's Story About What ...                         0
#
# Title                                               ...  \
# Title                                               ...
# 13 Little Blue Envelopes                            ...
# 1491: New Revelations of the Americas Before Co...  ...
# 1632 (The Assiti Shards)                            ...
# 1906                                                ...
# 23 Minutes In Hell: One Man's Story About What ...  ...
#
# Title                                               Wizard's First Rule (Sword of Truth, Book 1)  \
# Title
# 13 Little Blue Envelopes                                                                       0
# 1491: New Revelations of the Americas Before Co...                                             0
# 1632 (The Assiti Shards)                                                                       3
# 1906                                                                                           0
# 23 Minutes In Hell: One Man's Story About What ...                                             0
#
# Title                                               Words That Work: It's Not What You Say, It's What People Hear  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                  0
# 1632 (The Assiti Shards)                                                                            0
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  0
#
# Title                                               Wuthering Heights  \
# Title
# 13 Little Blue Envelopes                                            0
# 1491: New Revelations of the Americas Before Co...                  3
# 1632 (The Assiti Shards)                                            0
# 1906                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                  0
#
# Title                                               Year of Wonders (Turtleback School & Library Binding Edition)  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                  5
# 1632 (The Assiti Shards)                                                                            0
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  0
#
# Title                                               Yours Until Dawn  \
# Title
# 13 Little Blue Envelopes                                           0
# 1491: New Revelations of the Americas Before Co...                 0
# 1632 (The Assiti Shards)                                           0
# 1906                                                               0
# 23 Minutes In Hell: One Man's Story About What ...                 0
#
# Title                                               Zane's Afterburn: A Novel  \
# Title
# 13 Little Blue Envelopes                                                    0
# 1491: New Revelations of the Americas Before Co...                          0
# 1632 (The Assiti Shards)                                                    0
# 1906                                                                        0
# 23 Minutes In Hell: One Man's Story About What ...                          0
#
# Title                                               Zen Shorts (Caldecott Honor Book)  \
# Title
# 13 Little Blue Envelopes                                                            0
# 1491: New Revelations of the Americas Before Co...                                  0
# 1632 (The Assiti Shards)                                                            0
# 1906                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                  0
#
# Title                                               Zen in the Martial Arts  \
# Title
# 13 Little Blue Envelopes                                                  0
# 1491: New Revelations of the Americas Before Co...                        0
# 1632 (The Assiti Shards)                                                  0
# 1906                                                                      0
# 23 Minutes In Hell: One Man's Story About What ...                        0
#
# Title                                               comeback - a mother and daughter's journey through hell and back  \
# Title
# 13 Little Blue Envelopes                                                                            0
# 1491: New Revelations of the Americas Before Co...                                                  0
# 1632 (The Assiti Shards)                                                                            0
# 1906                                                                                                0
# 23 Minutes In Hell: One Man's Story About What ...                                                  0
#
# Title                                               the Picture of Dorian Gray
# Title
# 13 Little Blue Envelopes                                                     0
# 1491: New Revelations of the Americas Before Co...                           2
# 1632 (The Assiti Shards)                                                     0
# 1906                                                                         0
# 23 Minutes In Hell: One Man's Story About What ...                           0
#
# [5 rows x 380 columns]

# %%
# Transition pronability matrix M
A = W.to_numpy().astype(float)   # A[i, j] = weight from book j to book i

# Column sums: total outgoing weight from each book j
col_sums = A.sum(axis=0)

# Handle dangling nodes (books with no outgoing edges)
dangling = (col_sums == 0)
if np.any(dangling):
    A[:, dangling] = 1.0  # For dangling columns, pretend they link equally to all books
    col_sums = A.sum(axis=0)

# Normalize columns so that each column sums to 1
M_np = A / col_sums

M = pd.DataFrame(M_np, index=W.index, columns=W.columns)

# %%
print(M.shape)
print("Column sums (=1):")
print(M.sum(axis=0))
# Out:
# (380, 380)
# Column sums (should be ~1):
# Title
# 13 Little Blue Envelopes                                                                           1.0
# 1491: New Revelations of the Americas Before Columbus                                              1.0
# 1632 (The Assiti Shards)                                                                           1.0
# 1906                                                                                               1.0
# 23 Minutes In Hell: One Man's Story About What He Saw, Heard, and Felt in that Place of Torment    1.0
#                                                                                                   ...
# Zane's Afterburn: A Novel                                                                          1.0
# Zen Shorts (Caldecott Honor Book)                                                                  1.0
# Zen in the Martial Arts                                                                            1.0
# comeback - a mother and daughter's journey through hell and back                                   1.0
# the Picture of Dorian Gray                                                                         1.0
# Length: 380, dtype: float64

# %% [markdown]
# ##### **4. Apply PageRank-based Link Analysis**
#
#
# ---
#
#
#
#
# *   Mathematical term: `v'= βMv + (1-β)ı\n`

# %%
def pagerank(M, alpha=0.85, tol=1e-8, max_iter=100):
    M = M.to_numpy() if isinstance(M, pd.DataFrame) else M
    N = M.shape[0]
    p = np.ones(N) / N
    teleport = (1 - alpha) / N

    for _ in range(max_iter):
        p_new = alpha * (M @ p) + teleport
        if np.linalg.norm(p_new - p, 1) < tol:
            break
        p = p_new
    return p

# %%
scores = pagerank(M)

# Attach book titles
pagerank_scores = pd.Series(scores, index=M.index, name='PageRank')

# Sort from most important book to least
pagerank_scores = pagerank_scores.sort_values(ascending=False)

pagerank_scores = pd.DataFrame(pagerank_scores)
pagerank_scores
# Out:
#                                                     PageRank
# Title
# Jane Eyre (Large Print)                             0.026710
# Jane Eyre (New Windmill)                            0.026710
# The Picture of Dorian Gray                          0.022949
# the Picture of Dorian Gray                          0.022949
# The Picture of Dorian Gray (The Classic Collect...  0.022949
# ...                                                      ...
# APA: The Easy Way! (for APA 5th edition)            0.000468
# Ultra Black Hair Growth II 2000 Edition             0.000468
# Twenty Things Adopted Kids Wish Their Adoptive ...  0.000468
# Total Workday Control Using Microsoft Outlook: ...  0.000468
# Transforming the Difficult Child: The Nurtured ...  0.000468
#
# [380 rows x 1 columns]
