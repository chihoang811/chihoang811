# %% [markdown]
# <a href="https://colab.research.google.com/github/chihoang811/chihoang811/blob/main/PageRank_based_Link_analysis_on_Books/Book_ratings_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***PageRank based Link Analysis on Books*** - Linh Chi HOANG
#
# *(Considering the similarity in book titles)*
#
#
# ---

# %% [markdown]
# ##### **1. Download Datasets**
#
#
# ---
#
#
#
#
# *   Please access your Kaggle account and download your API tokens for uploading the kaggle.json file and downloading the datasets
# *   For this project, only rating dataset was used

# %%
from google.colab import files
print("Please upload your kaggle.json file.")
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2025.11.12)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.5.1)

# %%
# !kaggle datasets download mohamedbakhet/amazon-books-reviews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mohamedbakhet/amazon-books-reviews
# License(s): CC0-1.0
# Downloading amazon-books-reviews.zip to /content
# 100% 1.06G/1.06G [00:12<00:00, 213MB/s]
# 100% 1.06G/1.06G [00:12<00:00, 88.1MB/s]

# %%
# !unzip amazon-books-reviews.zip
# Out:
# Archive:  amazon-books-reviews.zip
#   inflating: Books_rating.csv
#   inflating: books_data.csv

# %%
import pandas as pd
book_rating = pd.read_csv("Books_rating.csv")

# %% [markdown]
# ##### **2. Parameters settings**
#
#
# ---
#
#
# *   Note: Because of the limiation in RAM, this project used only popular books, which have at least 81 unique users

# %%
USE_SUBSAMPLE = True
MIN_RATING = 4 # keep onlybooks with score >= 4
MIN_USERS_PER_BOOK = 81 # choose only books rated by at least 81 users
MIN_SHARED_USERS_FOR_EDGES = 2 # edges are created only if for each pair of book there are at least 2 mutual users rating them
JACC_THRESHOLD = 0.6 # minimum exact Jaccard similarity required to consider two book titles as similar
LSH_THRESHOLD = 0.5 # similarity threshold used in the MinHash-based locality-sensitive hashing (LSH) stage to generate candidate pairs of similar titles
NUM_PERM =128 # number of permutation

# %% [markdown]
# ##### **3. Data Preprocessing with dataset *book_ratings***
#
#
# ---
#
#
# *   Choose only books with **review/score ≥ 4.0**
# *   Check NAN values
# *   Normalize book titles
# *   Check similar book titles (using MinHash signatures (with LSH) and Jaccard similarity)
# *   Create Weight matrix W
# *   Create Transition matrix M

# %%
# Check for NaN values
nan_check = book_rating.isnull()
print(nan_check.sum())

# Remove rows with NaN values
book_rating = book_rating.dropna()
# Out:
# Id                          0
# Title                     208
# Price                 2518829
# User_id                561787
# profileName            561905
# review/helpfulness          0
# review/score                0
# review/time                 0
# review/summary            407
# review/text                 8
# dtype: int64

# %%
# Normalize the titles (Because there are some books whose titles are the same but written in different forms)
import re

def normalized_title(t):
    t = t.lower().strip()
    t = re.sub(r'[^a-z0-9 ]+', '', t)   # remove punctuation
    t = re.sub(r'\s+', ' ', t)          # collapse spaces
    return t

book_rating['Title_cleaned'] = book_rating['Title'].apply(normalized_title)

# Filter ratings (>= 4) and select Title
filtered_books = book_rating[book_rating['review/score'] >= MIN_RATING][['Title_cleaned', 'User_id', 'review/score']]

# %%
# Count how many unique users rated each book
book_user_counts = filtered_books.groupby("Title_cleaned")["User_id"].nunique()

if USE_SUBSAMPLE:
  # Keep only books with at least 81 unique users
  popular_books = book_user_counts[book_user_counts >= MIN_USERS_PER_BOOK].index
  filtered_books = filtered_books[filtered_books["Title_cleaned"].isin(popular_books)]
else:
 popular_books = book_user_counts.index

# %%
filtered_books
# Out:
#                                     Title_cleaned         User_id  \
# 38660    gods and kings chronicles of the kings 1   A7IMBNFYANPNV
# 38661    gods and kings chronicles of the kings 1  A1WV4Q44JE40UF
# 38662    gods and kings chronicles of the kings 1  A32MYDPSMCHT1L
# 38663    gods and kings chronicles of the kings 1   AAOJ5T6VS5Z6O
# 38664    gods and kings chronicles of the kings 1  A2X1OYBRURS04R
# ...                                           ...             ...
# 2994351               first 100 words bright baby   AIFSOGUNXFADJ
# 2994352               first 100 words bright baby  A2B9B5F9FQ4JJ8
# 2994354               first 100 words bright baby  A2G9EZ3R716RH1
# 2994355               first 100 words bright baby  A37P45ZC5DSAJJ
# 2994356               first 100 words bright baby  A2LGDRB4P9DFG5
#
#          review/score
# 38660             5.0
# 38661             5.0
# 38662             5.0
# 38663             5.0
# 38664             5.0
# ...               ...
# 2994351           5.0
# 2994352           4.0
# 2994354           4.0
# 2994355           5.0
# 2994356           5.0
#
# [75789 rows x 3 columns]

# %% [markdown]
# ###### *Apllying MinHash (with LSH), and Jaacard similarity*

# %%
# Number of unique titles
nunique_titles = filtered_books["Title_cleaned"].nunique()
print("Number of unique cleaned title:", nunique_titles)
# Out:
# Number of unique cleaned title: 378

# %%
# Convert each normalized title into a set of words
def title_to_set(title):
    return set(title.split())

# %%
titles = filtered_books["Title_cleaned"].unique()
title_tokens = {t: title_to_set(t) for t in titles}

# %%
# !pip install datasketch
# Out:
# Requirement already satisfied: datasketch in /usr/local/lib/python3.12/dist-packages (1.8.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.12/dist-packages (from datasketch) (2.0.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasketch) (1.16.3)

# %%
# Build MinHash signatures
from datasketch import MinHash

def build_minhash(token_set, num_perm=128):
    m = MinHash(num_perm=num_perm)
    for token in token_set:
        m.update(token.encode("utf8"))
    return m

minhashes = {t: build_minhash(tok, num_perm=NUM_PERM) for t, tok in title_tokens.items()}

# %%
# Build LSH Index and insert signatures
from datasketch import MinHashLSH

lsh = MinHashLSH(
    threshold = LSH_THRESHOLD,
    num_perm = NUM_PERM
)

for title, mh in minhashes.items():
    lsh.insert(title, mh)

# %%
# Retrieve similar titles by LSH
candidate_pairs = set()

for title, mh in minhashes.items():
    for candidate in lsh.query(mh):
        if title == candidate:
          continue
        candidate_pairs.add(tuple(sorted((title, candidate))))

print("Candidate pairs from LSH:", len(candidate_pairs))
# Out:
# Candidate pairs from LSH: 53

# %%
# Jaccard similarity function
def jaccard_similarity(set1, set2):
    if not set1 and not set2:
        return 0.0
    return len(set1 & set2) / len(set1|set2)

# %%
# Apply Jaccard function to verify similar pairs
similarities = []

for t1, t2 in candidate_pairs:
    sim = jaccard_similarity(title_tokens[t1], title_tokens[t2])
    if sim >= JACC_THRESHOLD:
      similarities.append((t1, t2, sim))

print("Verified similar pairs from Jaccard:", len(similarities))

similar_df = pd.DataFrame(similarities, columns=['Title1', 'Title2', 'Sim']).sort_values("Sim", ascending=False)
similar_df
# Out:
# Verified similar pairs from Jaccard: 10
#                                               Title1  \
# 0  the picture of dorian gray classic collection ...
# 6                         the picture of dorian gray
# 2  lord of chaos turtleback school library bindin...
# 1  harrington on hold em expert strategy for no l...
# 9  a crown of swords turtleback school library bi...
# 3  a crown of swords turtleback school library bi...
# 7   exodus turtleback school library binding edition
# 8   exodus turtleback school library binding edition
# 5  the lorax turtleback school library binding ed...
# 4                                    up from slavery
#
#                                               Title2       Sim
# 0  the picture of dorian gray the classic collection  0.777778
# 6  the picture of dorian gray the classic collection  0.714286
# 2  shadow rising turtleback school library bindin...  0.692308
# 1  harrington on hold em expert strategy for no l...  0.687500
# 9  shadow rising turtleback school library bindin...  0.642857
# 3  lord of chaos turtleback school library bindin...  0.642857
# 7  the lorax turtleback school library binding ed...  0.625000
# 8  maniac magee turtleback school library binding...  0.625000
# 5  the tao of pooh turtleback school library bind...  0.600000
# 4                   up from slavery an autobiography  0.600000

# %% [markdown]
# ###### *Merge similar book titles*

# %%
# Build clusters of similar titles
jaccard_filtered = similar_df[similar_df["Sim"] >= JACC_THRESHOLD].copy()


clusters = []
visited = set()

# We will treat each connected group of titles as a cluster
for t in pd.unique(jaccard_filtered[['Title1', 'Title2']].values.ravel()):
    if t in visited:
        continue

    # start a new cluster with this title
    group = {t}
    changed = True

    # keep adding titles that are linked to any title in the group
    while changed:
        changed = False
        for _, row in jaccard_filtered.iterrows():
            a, b = row['Title1'], row['Title2']
            if a in group and b not in group:
                group.add(b)
                changed = True
            elif b in group and a not in group:
                group.add(a)
                changed = True

    visited |= group
    clusters.append(group)

print("Number of clusters:", len(clusters))
# Out:
# Number of clusters: 5

# %%
# Choose one canonical title per cluster
def choose_canonical(group):
    return min(group, key=len)

mapping = {}

for group in clusters:
    canon = choose_canonical(group)
    for t in group:
        mapping[t] = canon

filtered_books['Title_final'] = filtered_books['Title_cleaned'].map(mapping).fillna(filtered_books['Title_cleaned'])

# %%
filtered_books = filtered_books[['Title_final', 'User_id', 'review/score']]
filtered_books
# Out:
#                                       Title_final         User_id  \
# 38660    gods and kings chronicles of the kings 1   A7IMBNFYANPNV
# 38661    gods and kings chronicles of the kings 1  A1WV4Q44JE40UF
# 38662    gods and kings chronicles of the kings 1  A32MYDPSMCHT1L
# 38663    gods and kings chronicles of the kings 1   AAOJ5T6VS5Z6O
# 38664    gods and kings chronicles of the kings 1  A2X1OYBRURS04R
# ...                                           ...             ...
# 2994351               first 100 words bright baby   AIFSOGUNXFADJ
# 2994352               first 100 words bright baby  A2B9B5F9FQ4JJ8
# 2994354               first 100 words bright baby  A2G9EZ3R716RH1
# 2994355               first 100 words bright baby  A37P45ZC5DSAJJ
# 2994356               first 100 words bright baby  A2LGDRB4P9DFG5
#
#          review/score
# 38660             5.0
# 38661             5.0
# 38662             5.0
# 38663             5.0
# 38664             5.0
# ...               ...
# 2994351           5.0
# 2994352           4.0
# 2994354           4.0
# 2994355           5.0
# 2994356           5.0
#
# [75789 rows x 3 columns]

# %% [markdown]
# ###### *Create the Transition matrix M*

# %%
# For each pair of books, count how many users liked both
import numpy as np
from scipy.sparse import coo_matrix, csr_matrix, csc_matrix

# Remove duplicated (User_id, Title) pairs
df = filtered_books[["User_id", "Title_final"]].drop_duplicates()

# Convert User_id and Title into integer IDs
user_codes, user_index = pd.factorize(df["User_id"], sort=True)
title_codes, title_index = pd.factorize(df["Title_final"], sort=True)

n_users = len(user_index)
n_titles = len(title_index)

# Build matrix B (users x titles): B[u, t] = 1 if user u liked title t
data = np.ones(len(df), dtype=np.int8)
B = coo_matrix((data, (user_codes, title_codes)), shape=(n_users, n_titles)).tocsr()

# Shared-users matrix W (titles x titles): W[i, j] = #users who liked both titles
W = (B.T @ B).tocsr()

# Remove self-counts on the diagonal
W.setdiag(0)
W.eliminate_zeros()

print("W shape:", W.shape)
print("Nonzero edges:", W.nnz)
# Out:
# W shape: (369, 369)
# Nonzero edges: 18348

# %%
# Keep only strong edges
W = W.multiply(W >= MIN_SHARED_USERS_FOR_EDGES)

W_df = pd.DataFrame(W.toarray(), index=title_index, columns=title_index)
W_df.head()
# Out:
#                                                     13 little blue envelopes  \
# 13 little blue envelopes                                                   0
# 1491 new revelations of the americas before col...                         0
# 1632 the assiti shards                                                     0
# 1906                                                                       0
# 23 minutes in hell one mans story about what he...                         0
#
#                                                     1491 new revelations of the americas before columbus  \
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
#                                                     1632 the assiti shards  \
# 13 little blue envelopes                                                 0
# 1491 new revelations of the americas before col...                       0
# 1632 the assiti shards                                                   0
# 1906                                                                     0
# 23 minutes in hell one mans story about what he...                       0
#
#                                                     1906  \
# 13 little blue envelopes                               0
# 1491 new revelations of the americas before col...     0
# 1632 the assiti shards                                 0
# 1906                                                   0
# 23 minutes in hell one mans story about what he...     0
#
#                                                     23 minutes in hell one mans story about what he saw heard and felt in that place of torment  \
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
#                                                     500 lowcarb recipes 500 recipes from snacks to dessert that the whole family will love  \
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
#                                                     a breath of snow and ashes outlander  \
# 13 little blue envelopes                                                               0
# 1491 new revelations of the americas before col...                                     0
# 1632 the assiti shards                                                                 0
# 1906                                                                                   0
# 23 minutes in hell one mans story about what he...                                     0
#
#                                                     a bride most begrudging  \
# 13 little blue envelopes                                                  0
# 1491 new revelations of the americas before col...                        0
# 1632 the assiti shards                                                    0
# 1906                                                                      0
# 23 minutes in hell one mans story about what he...                        0
#
#                                                     a caress of twilight meredith gentry book 2  \
# 13 little blue envelopes                                                                      0
# 1491 new revelations of the americas before col...                                            0
# 1632 the assiti shards                                                                        2
# 1906                                                                                          0
# 23 minutes in hell one mans story about what he...                                            0
#
#                                                     a certain slant of light  \
# 13 little blue envelopes                                                   3
# 1491 new revelations of the americas before col...                         0
# 1632 the assiti shards                                                     0
# 1906                                                                       0
# 23 minutes in hell one mans story about what he...                         0
#
#                                                     ...  \
# 13 little blue envelopes                            ...
# 1491 new revelations of the americas before col...  ...
# 1632 the assiti shards                              ...
# 1906                                                ...
# 23 minutes in hell one mans story about what he...  ...
#
#                                                     why men love bitches from doormat to dreamgirl a womans guide to holding her own in a relationship  \
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
#                                                     wicked the grimmerie a behindthescenes look at the hit broadway musical  \
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
#                                                     wizards first rule sword of truth book 1  \
# 13 little blue envelopes                                                                   0
# 1491 new revelations of the americas before col...                                         0
# 1632 the assiti shards                                                                     3
# 1906                                                                                       0
# 23 minutes in hell one mans story about what he...                                         0
#
#                                                     words that work its not what you say its what people hear  \
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  0
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
#                                                     wuthering heights  \
# 13 little blue envelopes                                            0
# 1491 new revelations of the americas before col...                  3
# 1632 the assiti shards                                              0
# 1906                                                                0
# 23 minutes in hell one mans story about what he...                  0
#
#                                                     year of wonders turtleback school library binding edition  \
# 13 little blue envelopes                                                                            0
# 1491 new revelations of the americas before col...                                                  5
# 1632 the assiti shards                                                                              0
# 1906                                                                                                0
# 23 minutes in hell one mans story about what he...                                                  0
#
#                                                     yours until dawn  \
# 13 little blue envelopes                                           0
# 1491 new revelations of the americas before col...                 0
# 1632 the assiti shards                                             0
# 1906                                                               0
# 23 minutes in hell one mans story about what he...                 0
#
#                                                     zanes afterburn a novel  \
# 13 little blue envelopes                                                  0
# 1491 new revelations of the americas before col...                        0
# 1632 the assiti shards                                                    0
# 1906                                                                      0
# 23 minutes in hell one mans story about what he...                        0
#
#                                                     zen in the martial arts  \
# 13 little blue envelopes                                                  0
# 1491 new revelations of the americas before col...                        0
# 1632 the assiti shards                                                    0
# 1906                                                                      0
# 23 minutes in hell one mans story about what he...                        0
#
#                                                     zen shorts caldecott honor book
# 13 little blue envelopes                                                          0
# 1491 new revelations of the americas before col...                                0
# 1632 the assiti shards                                                            0
# 1906                                                                              0
# 23 minutes in hell one mans story about what he...                                0
#
# [5 rows x 369 columns]

# %%
# Build transition probability matrix M
# W: sparse (n x n), W[i, j] = weight from book j to i
W = W.tocsc().astype(float)
n = W.shape[0]

col_sums = np.asarray(W.sum(axis=0)).ravel()
dangling = (col_sums == 0)

M = W.copy()

# Normalize non-dangling columns
for j in np.where(~dangling)[0]:
    start, end = M.indptr[j], M.indptr[j + 1]
    if start < end:
        M.data[start:end] /= col_sums[j]

# Fill dangling columns efficiently
if np.any(dangling):
    M = M.tolil()
    for j in np.where(dangling)[0]:
        M[:, j] = 1.0 / n
    M = M.tocsr()
else:
    M = M.tocsr()

col_check = np.asarray(M.sum(axis=0)).ravel()
print("M shape:", M.shape)
print("Column sums in [min, max]:", col_check.min(), col_check.max())
# Out:
# M shape: (369, 369)
# Column sums in [min, max]: 0.9999999999999984 1.0000000000000033

# %% [markdown]
# ##### **4. Apply PageRank-based Link Analysis**
#
#
# ---
#
#
#
#
# *   Mathematical term: `v'= βMv + (1-β)e/n`

# %%
def pagerank(M, alpha=0.85, tol=1e-8, max_iter=100):
    if isinstance(M, pd.DataFrame):
        M = M.values

    N = M.shape[0]
    p = np.ones(N) / N
    teleport = np.ones(N) / N

    for _ in range(max_iter):
        p_new = alpha * (M @ p) + (1 - alpha) * teleport
        if np.linalg.norm(p_new - p, 1) < tol:
            break
        p = p_new

    return p / p.sum()

# %%
scores = pagerank(M)

# Attach book titles
pagerank_scores = pd.Series(scores, index=title_index, name='PageRank')

# Sort from most important book to least
pagerank_scores = pagerank_scores.sort_values(ascending=False)

pagerank_scores = pd.DataFrame(pagerank_scores)
pagerank_scores
# Out:
#                                                     PageRank
# jane eyre new windmill                              0.019044
# jane eyre large print                               0.019044
# wuthering heights                                   0.017165
# a tale of two cities literary touchstone edition    0.015809
# great expectations                                  0.015330
# ...                                                      ...
# cliffstestprep math review for standardized tes...  0.000485
# the wealthy spirit daily affirmations for finan...  0.000485
# the whole foods allergy cookbook two hundred go...  0.000485
# twenty things adopted kids wish their adoptive ...  0.000485
# ultra black hair growth ii 2000 edition             0.000485
#
# [369 rows x 1 columns]
